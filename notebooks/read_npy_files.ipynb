# %%
import numpy as np
W1 = np.load('../data/models/sample/current/W1.npy')
print(W1.shape)    # (7, 32)
print(W1[0])       # first stock's embedding
# Out:
# (7, 32)
# [ 0.22490016 -0.15411983  0.14400052  0.721446   -0.68402976  0.01240466
#   0.08037978 -0.44844365 -0.03226319 -0.23253055  0.04554828  0.09864625
#   0.07415614  0.40779385 -0.02455298 -0.19568188  0.14248729 -0.26229584
#   0.21075311  0.0646551  -0.13585733 -0.23954941 -0.19115156 -0.02952187
#   0.20249034  0.03564069 -0.2579244  -0.01719898 -0.05631877 -0.3647252
#   0.1101929   0.03111335]
